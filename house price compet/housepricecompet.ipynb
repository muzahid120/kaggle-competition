# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df1=pd.read_csv(r'c:\Users\SDS\Documents\house price\train.csv')
df2=pd.read_csv(r'c:\Users\SDS\Documents\house price\test.csv')

# %%
df=pd.concat([df1,df2])

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)
df.isnull().mean()*100
# Out:
# Id                0.000000
# MSSubClass        0.000000
# MSZoning          0.137033
# LotFrontage      16.649538
# LotArea           0.000000
# Street            0.000000
# Alley            93.216855
# LotShape          0.000000
# LandContour       0.000000
# Utilities         0.068517
# LotConfig         0.000000
# LandSlope         0.000000
# Neighborhood      0.000000
# Condition1        0.000000
# Condition2        0.000000
# BldgType          0.000000
# HouseStyle        0.000000
# OverallQual       0.000000
# OverallCond       0.000000
# YearBuilt         0.000000
# YearRemodAdd      0.000000
# RoofStyle         0.000000
# RoofMatl          0.000000
# Exterior1st       0.034258
# Exterior2nd       0.034258
# MasVnrType       60.500171
# MasVnrArea        0.787941
# ExterQual         0.000000
# ExterCond         0.000000
# Foundation        0.000000
# BsmtQual          2.774923
# BsmtCond          2.809181
# BsmtExposure      2.809181
# BsmtFinType1      2.706406
# ...

# %%
# remove columns more than 45% data missing in columns
df.drop(columns=['Alley','MiscFeature','Fence','PoolQC','FireplaceQu','MasVnrType','Id'],inplace=True,axis=1)

# %%
df['MSZoning']=df['MSZoning'].fillna(df['MSZoning'].mode()[0])
df['LotFrontage']=df['LotFrontage'].fillna(df['LotFrontage'].mean())
df['Utilities']=df['Utilities'].fillna(df['Utilities'].mode()[0])
df['Exterior1st']=df['Exterior1st'].fillna(df['Exterior1st'].mode()[0])
df['Exterior2nd']=df['Exterior2nd'].fillna(df['Exterior2nd'].mode()[0])
df['MasVnrArea']=df['MasVnrArea'].fillna(df['MasVnrArea'].mean())
df['BsmtQual']=df['BsmtQual'].fillna(df['BsmtQual'].mode()[0])
df['BsmtCond']=df['BsmtCond'].fillna(df['BsmtCond'].mode()[0])
df['BsmtExposure']=df['BsmtExposure'].fillna(df['BsmtExposure'].mode()[0])
df['BsmtFinType1']=df['BsmtFinType1'].fillna(df['BsmtFinType1'].mode()[0])
df['BsmtFinSF1']=df['BsmtFinSF1'].fillna(df['BsmtFinSF1'].mean())
df['BsmtFinType2']=df['BsmtFinType2'].fillna(df['BsmtFinType2'].mode()[0])
df['BsmtFinSF2']=df['BsmtFinSF2'].fillna(df['BsmtFinSF2'].mean())
df['BsmtUnfSF']=df['BsmtUnfSF'].fillna(df['BsmtUnfSF'].mean())
df['TotalBsmtSF']=df['TotalBsmtSF'].fillna(df['TotalBsmtSF'].mean())
df['Electrical']=df['Electrical'].fillna(df['Electrical'].mode()[0])
df['BsmtFullBath']=df['BsmtFullBath'].fillna(df['BsmtFullBath'].mode()[0])
df['BsmtHalfBath']=df['BsmtHalfBath'].fillna(df['BsmtHalfBath'].mode()[0])
df['KitchenQual']=df['KitchenQual'].fillna(df['KitchenQual'].mode()[0])
df['Functional']=df['Functional'].fillna(df['Functional'].mode()[0])
df['GarageType']=df['GarageType'].fillna(df['GarageType'].mode()[0])
df['GarageYrBlt']=df['GarageYrBlt'].fillna(df['GarageYrBlt'].mode()[0])
df['GarageFinish']=df['GarageFinish'].fillna(df['GarageFinish'].mode()[0])
df['GarageCars']=df['GarageCars'].fillna(df['GarageCars'].mode()[0])
df['GarageArea']=df['GarageArea'].fillna(df['GarageArea'].mean())
df['GarageQual']=df['GarageQual'].fillna(df['GarageQual'].mode()[0])
df['GarageCond']=df['GarageCond'].fillna(df['GarageCond'].mode()[0])
df['SaleType']=df['SaleType'].fillna(df['SaleType'].mode()[0])

# %%
df.isnull().sum()
# Out:
# MSSubClass          0
# MSZoning            0
# LotFrontage         0
# LotArea             0
# Street              0
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrArea          0
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual            0
# BsmtCond            0
# BsmtExposure        0
# BsmtFinType1        0
# BsmtFinSF1          0
# BsmtFinType2        0
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# CentralAir          0
# Electrical          0
# 1stFlrSF            0
# ...

# %%
categorical_col=df.select_dtypes(include=['object']).columns

# %%
for i in categorical_col:
    sns.barplot(df[i])
    plt.show()

# %%
numeric_columns=df.select_dtypes(exclude=['object']).columns

# %%
def category_onehot_multcols(multcolumns):
    df_final=df
    i=0
    for fields in multcolumns:
        
        
        df1=pd.get_dummies(df[fields],drop_first=True)
        
        df.drop([fields],axis=1,inplace=True)
        if i==0:
            df_final=df1.copy()
        else:
            
            df_final=pd.concat([df_final,df1],axis=1)
        i=i+1
       
        
    df_final=pd.concat([df,df_final],axis=1)
        
    return df_final

# %%
final_df=category_onehot_multcols(categorical_col)
final_df.shape
# Out:
# (2919, 230)

# %%
final_df.columns.duplicated().sum()
# Out:
# 54

# %%
# drop duplicated columns
final_df = final_df.loc[:, ~final_df.columns.duplicated()]

# %%
final_df.shape
# Out:
# (2919, 176)

# %%
train_df=final_df.iloc[:1460,:]
test_df=final_df.iloc[1460:,:]
print(train_df.shape,test_df.shape)
# Out:
# (1460, 176) (1459, 176)

# %%
# Assuming final_df is your DataFrame
correlation_with_saleprice = final_df.corr()['SalePrice'].sort_values(ascending=False)
print(correlation_with_saleprice)
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# PConc            0.497734
# MasVnrArea       0.475210
# Fireplaces       0.466929
# Gd               0.452466
# GLQ              0.434597
# NridgHt          0.402149
# GarageYrBlt      0.397778
# BsmtFinSF1       0.386420
# New              0.357509
# Partial          0.352060
# LotFrontage      0.334820
# NoRidge          0.330424
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# VinylSd          0.305009
# HalfBath         0.284108
# LotArea          0.263843
# Y                0.251328
# RL               0.245063
# 2Story           0.242880
# SBrkr            0.242357
# Hip              0.235897
# BuiltIn          0.235449
# ...

# %%
threshold = 0.5
correlation_above_threshold = correlation_with_saleprice[correlation_with_saleprice.abs() > threshold]
print(correlation_above_threshold)
# Out:
# SalePrice       1.000000
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# TA             -0.589044
# Name: SalePrice, dtype: float64

# %%
for i in numeric_columns:

    percentile25=train_df[i].quantile(0.25)
    percentile75=train_df[i].quantile(0.75)
    iqr=percentile75-percentile25
    upperlimit=percentile75+1.5*iqr
    lowerlimit=percentile25-1.5*iqr

    train_df[i]=np.where(train_df[i]>=upperlimit,upperlimit,
    np.where(train_df[i]<=lowerlimit,lowerlimit,train_df[i]))
# Out:
# C:\Users\SDS\AppData\Local\Temp\ipykernel_15536\1338799734.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[i]=np.where(train_df[i]>=upperlimit,upperlimit,
# C:\Users\SDS\AppData\Local\Temp\ipykernel_15536\1338799734.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[i]=np.where(train_df[i]>=upperlimit,upperlimit,
# C:\Users\SDS\AppData\Local\Temp\ipykernel_15536\1338799734.py:9: SettingWithCopyWarning:
# ...

# %%
for i in numeric_columns:
    sns.boxplot(train_df[i])
    plt.show()

# %%
test_df.drop(columns=['SalePrice'],axis=1,inplace=True)
# Out:
# C:\Users\SDS\AppData\Local\Temp\ipykernel_15536\3572703214.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df.drop(columns=['SalePrice'],axis=1,inplace=True)

# %%
remove_col=['SalePrice']
num_col=[col for col in numeric_columns if col not in remove_col]

# %%
for i in num_col:

    percentile25=test_df[i].quantile(0.25)
    percentile75=test_df[i].quantile(0.75)
    iqr=percentile75-percentile25
    upperlimit=percentile75+1.5*iqr
    lowerlimit=percentile25-1.5*iqr

    test_df[i]=np.where(test_df[i]>=upperlimit,upperlimit,
    np.where(test_df[i]<=lowerlimit,lowerlimit,test_df[i]))
# Out:
# C:\Users\SDS\AppData\Local\Temp\ipykernel_15536\3010015750.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df[i]=np.where(test_df[i]>=upperlimit,upperlimit,
# C:\Users\SDS\AppData\Local\Temp\ipykernel_15536\3010015750.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df[i]=np.where(test_df[i]>=upperlimit,upperlimit,
# C:\Users\SDS\AppData\Local\Temp\ipykernel_15536\3010015750.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
x_train=train_df.drop(columns=['SalePrice'])
y_train=train_df['SalePrice']

# %%
from sklearn.preprocessing import PowerTransformer,KBinsDiscretizer

# %%
from sklearn.preprocessing import PowerTransformer, KBinsDiscretizer

pt = PowerTransformer()
kb = KBinsDiscretizer(n_bins=15, encode='ordinal', strategy='quantile')

# Check the num_col variable
print("num_col:", num_col)

# Check the shape of x_train and x_train_transform
print("x_train shape:", x_train.shape)
print("x_train_transform shape:", x_train_transform.shape)

# Check the index of x_train_transform[num_col]
print("Index of x_train_transform[num_col]:")

# Try to assign values again
x_train[num_col]=pt.fit_transform(x_train[num_col])
test_df[num_col]=pt.transform(test_df[num_col])
# Out:
# num_col: ['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']
# x_train shape: (1460, 175)
# x_train_transform shape: (1460, 36)
# Index of x_train_transform[num_col]:
# c:\Users\SDS\.conda\envs\test2\lib\site-packages\numpy\core\_methods.py:239: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# C:\Users\SDS\AppData\Local\Temp\ipykernel_15536\2459925975.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
test_df.head(5)
# Out:
#    MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   -1.165889     0.635575  0.567748    -0.783664     0.575812  -0.500205
# 1   -1.165889     0.692736  1.262634    -0.032491     0.575812  -0.592415
# 2    0.495750     0.291292  1.149376    -0.783664    -0.499545   0.868775
# 3    0.495750     0.521068  0.123040    -0.032491     0.575812   0.914709
# 4    1.431975    -1.531629 -1.309194     1.347033    -0.499545   0.646188
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0     -1.175682   -0.828051    0.550453         0.0  -0.480830    -0.400409
# 1     -1.267783    1.102554    0.976514         0.0  -0.116155     0.707514
# 2      0.559661   -0.828051    0.873711         0.0  -0.949173    -0.284026
# 3      0.559661    0.647083    0.700620         0.0  -0.326639    -0.289074
# 4      0.184672   -0.828051    0.238171         0.0   1.019792     0.588287
#
# ...

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbr=GradientBoostingRegressor(learning_rate=0.01,max_depth=10,n_estimators=200,alpha=0.01,)

# %%
gbr.fit(x_train.values,y_train.values)
# Out:
# GradientBoostingRegressor(alpha=0.01, learning_rate=0.01, max_depth=10,
#                           n_estimators=200)

# %%
y_pred=gbr.predict(test_df.values)
y_pred
# Out:
# array([138035.18114416, 156859.50807594, 176258.6838212 , ...,
#        155470.03949185, 118748.52050549, 216156.92081291])

# %%
from sklearn.linear_model import Ridge
rg=Ridge(alpha=0.8)

# %%
rg.fit(x_train.values,y_train.values)
# Out:
# Ridge(alpha=0.8)

# %%
y_pred3=rg.predict(test_df.values)
y_pred3
# Out:
# array([110755.81387522, 165743.552806  , 190822.53056254, ...,
#        182829.8154159 , 109359.30438805, 228962.16259055])

# %%
from sklearn.svm import SVR

# %%
sv=SVR(kernel='linear', C=1.0)
sv.fit(x_train.values,y_train.values)
sv.predict(test_df.values)
# Out:
# array([154487.0698264 , 160890.76726218, 167919.42694346, ...,
#        162345.28433873, 157307.10878593, 172775.87792526])

# %%
import pickle

file_name='model_final.pkl'
pickle.dump(gbr,open(file_name,'wb'))

# %%
pred=pd.DataFrame(y_pred3)
submisson=pd.read_csv(r'C:\Users\SDS\Documents\house price\sample_submission.csv')
dataset=pd.concat([submisson['Id'],pred],axis=1)
dataset.columns=['Id','SalePrice']
#dataset['SalePrice']=np.sqrt(dataset['SalePrice']**2)

#dataset.to_csv('model_2.csv')

# %%
import tensorflow
from tensorflow import keras
from keras.layers import Dense
from keras.models import Sequential

# %%
model=Sequential()
model.add(Dense(64,activation='relu',input_dim=(175)))
model.add(Dense(32,activation='relu'))
model.add(Dense(1,activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_19 (Dense)            (None, 64)                11264
#
#  dense_20 (Dense)            (None, 32)                2080
#
#  dense_21 (Dense)            (None, 1)                 33
#
# ...
# Total params: 13377 (52.25 KB)
# Trainable params: 13377 (52.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.fit(x_train,y_train,epochs=100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[631], line 1
# ----> 1 model.fit(x_train,y_train,epochs=100)
#
# File c:\Users\SDS\.conda\envs\test2\lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\Users\SDS\.conda\envs\test2\lib\site-packages\tensorflow\python\framework\constant_op.py:98, in convert_to_eager_tensor(value, ctx, dtype)
#      96     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#      97 ctx.ensure_initialized()
# ---> 98 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# ...
